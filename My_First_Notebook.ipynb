# %% [markdown]
# My first markdown cell in Jupyter.

# %%
print("Hello, ITAI-2373-Natural Language Processing - HCC Summer 2026")
# Out:
# Hello, ITAI-2373-Natural Language Processing - HCC Summer 2026
